# %% [markdown]
# ### Display Metadata Table from Oracle XE Table
# A simple display of metadata queried from the Didap_Conn:
# * User: shruthik
# * Password: bin4 (for reference)
#
# ### Display Shown Below

# %%
# verify PATH environment variable
import os
print(os.environ['PATH'] + "\n")

# verify Python 32- or 64-bit shell mode
import struct
print("Python shell mode: ", struct.calcsize("P") * 8)

# %matplotlib inline

# import to use python pandas
import numpy as np
import pandas as pd

# import matplotlib for creating plots in pandas
import matplotlib.pyplot as plt
# Out:
# C:\oraclexe\app\oracle\product\11.2.0\server\bin;C:\WINDOWS\system32;C:\WINDOWS;C:\WINDOWS\System32\Wbem;C:\WINDOWS\System32\WindowsPowerShell\v1.0\;C:\WINDOWS\System32\OpenSSH\;C:\Program Files\Git\cmd;C:\Users\shrut\AppData\Local\Programs\Python\Python38;C:\Users\shrut\AppData\Local\Programs\Python\Python38\Scripts;
#
# Python shell mode:  64

# %%
# importing module 
import cx_Oracle

# initializes oci.dll file in provided path to connect cx_Oracle package with local Oracle XE instance
# cx_Oracle.init_oracle_client(config_dir=r"C:\oraclexe\app\oracle\product\11.2.0\server\bin")

# %%
try: 
    con = cx_Oracle.connect("shruthik/bin4@localhost")
    cursor = con.cursor()
    rs = cursor.execute("select * from metadata")
except cx_Oracle.DatabaseError as e: 
    print("Error connecting to Oracle DB Instance", e) 

# close db operation if error persists
finally: 
        if cursor: 
            cursor.close() 
        if con: 
            con.close()

# %%
'''
    for row in rs:
        print(row)
'''
# Out:
# '\n    for row in rs:\n        print(row)\n'

# %%
# for initial loading of extension
# %load_ext sql

# reloading extension for formality
# %reload_ext sql
# %sql oracle+cx_oracle://shruthik:bin4@localhost/
# %sql fullTable << select * from metadata
fullTable
# Out:
#  * oracle+cx_oracle://shruthik:***@localhost/
# 0 rows affected.
# Returning data to local variable fullTable
# [('hdfs://localhost.localdomain:8020/user/cloudera/MSTIFF_Code/REMUS001.mst', 20140721, '12:31:21', '12:31:20', 24.94837, -80.45407, 23.6, 23.5),
#  ('hdfs://localhost.localdomain:8020/user/cloudera/MSTIFF_Code/REMUS001.mst', 20140721, '12:31:35', '12:31:33', 24.94839, -80.45385, 24.6, 24.5),
#  ('hdfs://localhost.localdomain:8020/user/cloudera/MSTIFF_Code/REMUS001.mst', 20140721, '12:31:49', '12:31:48', 24.9484, -80.45367, 30.2, 28.7),
#  ('hdfs://localhost.localdomain:8020/user/cloudera/MSTIFF_Code/REMUS001.mst', 20140721, '12:32:3', '12:32:1', 24.94843, -80.4535, 30.2, 21.8),
#  ('hdfs://localhost.localdomain:8020/user/cloudera/MSTIFF_Code/REMUS001.mst', 20140721, '12:32:18', '12:32:18', 24.94845, -80.45335, 33.2, 21.8),
#  ('hdfs://localhost.localdomain:8020/user/cloudera/MSTIFF_Code/REMUS003.mst', 20140721, '12:19:57', '12:19:56', 24.94835, -80.45415, 21.4, 21.9),
# ...

# %%
fullTable_df = fullTable.DataFrame()
# fullTable_df.set_index(fullTable_df.filepath, inplace=True)
fullTable_df.info()
fullTable_df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 285 entries, 0 to 284
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   filepath      285 non-null    object
#  1   datestamp     285 non-null    int64
#  2   navtime       285 non-null    object
#  3   fathtime      285 non-null    object
#  4   latitude      285 non-null    float64
#  5   longitude     285 non-null    float64
#  6   waterdepth    285 non-null    float64
#  7   towfishdepth  285 non-null    float64
# dtypes: float64(4), int64(1), object(3)
# memory usage: 17.9+ KB
#           datestamp    latitude   longitude  waterdepth  towfishdepth
# count  2.850000e+02  285.000000  285.000000  285.000000    285.000000
# mean   2.014072e+07   24.948699  -80.453504   25.244211     15.455789
# std    3.401848e+00    0.000546    0.000744    4.969528      7.667235
# min    2.014072e+07   24.948070  -80.454260   17.400000      2.600000
# ...

# %% [markdown]
# ### Plotting Data

# %%
fullTable_df.plot.scatter(x='navtime', y='waterdepth', figsize=(15,30), c='DarkBlue', title="Water Depth vs. Nav Time")
# Out:
# <AxesSubplot:title={'center':'Water Depth vs. Nav Time'}, xlabel='navtime', ylabel='waterdepth'>
